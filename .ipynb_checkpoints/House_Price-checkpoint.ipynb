# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Price predictor/data_smartphone.csv')
# 3260 rows and 20 columns
# object, int64 and float 64 data types
#missing values in has_finegrprints and has_nfc and has_5g and num_core and refresh_rate(hz) 
# 33 unique brands

# %%
df['Price'].hist(bins=20)
# Out:
# <Axes: >

# %%
df['Price'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# obs 5 is that the data is right skwewed

# %%
x = df["RAM"]
y = df["Price"]
plt.scatter(x, y)
plt.xlabel("RAM")
plt.ylabel("Price")
plt.show()
